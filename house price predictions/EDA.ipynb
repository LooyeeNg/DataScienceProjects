# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# ### Load Data

# %%
import pandas as pd

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ### Shape & Column Names

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_test.shape
# Out:
# (1459, 80)

# %%
df_test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# The difference columns between the train set and the test set is 'SalePrice', which is the label feature.

# %% [markdown]
# ### Column Types

# %%
# list of numerical variables
numerical_features = [feature for feature in df_train.columns if df_train[feature].dtypes != 'O']
print('Total of numerical variables: ', len(numerical_features))
# Out:
# Total of numerical variables:  38

# %%
# list of variables that contain year information
year_features = [feature for feature in df_train if 'Yr' in feature or 'Year' in feature]
print("Year features in Numerical Variables Count: {} / {}".format(len(year_features),len(numerical_features)))

# year_features
# Out:
# Year features in Numerical Variables Count: 4 / 38

# %%
discrete_features=[feature for feature in numerical_features if len(df_train[feature].unique())<25 and feature not in year_features+['Id']]
print("Discrete Variables in Numerical Variables Count: {} / {}".format(len(discrete_features),len(numerical_features)))

# discrete_features
# Out:
# Discrete Variables in Numerical Variables Count: 17 / 38

# %%
continuous_features=[feature for feature in numerical_features if feature not in discrete_features+year_features+['Id']]
print("Continuous features in Numerical Variables Count: {} / {}".format(len(continuous_features),len(numerical_features)))

# continuous_features
# Out:
# Continuous features in Numerical Variables Count: 16 / 38

# %%
# list of categorical variables
categorical_features=[feature for feature in df_train.columns if df_train[feature].dtypes=='O']
print("Categorical Variables Count: {}".format(len(categorical_features)))
# Out:
# Categorical Variables Count: 43

# %% [markdown]
# ### EDA Discrete Variables in Numerical Variables

# %%
## Lets Find the realtionship between them and Sale Price

for feature in discrete_features:
    data=df_train.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %%
## Also, lets look at the distribution of these variables, not just their relationship with the target
    
for feature in discrete_features:
    data=df_train.copy()
    data[feature].hist()
    plt.xlabel(feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### EDA Continuous Variables in Numerical Variables

# %%
## Lets analyse the continuous values by creating histograms to understand the distribution
## setting number of bins equal to 25, could add more if wanted more granular picture
for feature in continuous_features:
    data=df_train.copy()
    data[feature].hist(bins=100)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
# Outliers
for feature in continuous_features:
    
    data=df_train.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# ### EDA Year Variables in Numerical Variables

# %%
# let's explore the content of these year variables
for feature in year_features:
    print(feature, df_train[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
## Lets analyze the Temporal Datetime Variables
## We will check whether there is a relation between year the house is sold and the sales price

df_train.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title("House Price vs YearSold")
# Out:
# Text(0.5, 1.0, 'House Price vs YearSold')

# %%
## Here we will compare the difference between All years feature with SalePrice

for feature in year_features:
    if feature!='YrSold':
        df=df_train.copy()
        ## We will capture the difference between year variable and year the house was sold for
        df[feature]=df['YrSold']-df[feature]

        plt.scatter(df[feature],df['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %% [markdown]
# ### EDA Categorical Variables

# %%
df_train[categorical_features].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
# ...

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(df_train[feature].unique())))
# Out:
# The feature is MSZoning and number of categories are 5
# The feature is Street and number of categories are 2
# The feature is Alley and number of categories are 3
# The feature is LotShape and number of categories are 4
# The feature is LandContour and number of categories are 4
# The feature is Utilities and number of categories are 2
# The feature is LotConfig and number of categories are 5
# The feature is LandSlope and number of categories are 3
# The feature is Neighborhood and number of categories are 25
# The feature is Condition1 and number of categories are 9
# The feature is Condition2 and number of categories are 8
# The feature is BldgType and number of categories are 5
# The feature is HouseStyle and number of categories are 8
# The feature is RoofStyle and number of categories are 6
# The feature is RoofMatl and number of categories are 8
# The feature is Exterior1st and number of categories are 15
# The feature is Exterior2nd and number of categories are 16
# ...

# %%
## Find out the relationship between categorical variable and dependent feature SalesPrice
for feature in categorical_features:
    data=df_train.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Missing Values, errors, or outlier values

# %%
# Show me the missing values and the propotion...
null_total = df_train.isnull().sum().sort_values(ascending=False)
null_percentage = (df_train.isnull().sum() / len(df_train)) * 100
missing_data = pd.concat([null_total, null_percentage], axis=1, keys=['Total', 'Percentage'])
only_missing_data = missing_data[missing_data['Percentage'] >= 0.01]
only_missing_data
# Out:
#               Total  Percentage
# PoolQC         1453   99.520548
# MiscFeature    1406   96.301370
# Alley          1369   93.767123
# Fence          1179   80.753425
# FireplaceQu     690   47.260274
# LotFrontage     259   17.739726
# GarageYrBlt      81    5.547945
# GarageCond       81    5.547945
# GarageType       81    5.547945
# GarageFinish     81    5.547945
# GarageQual       81    5.547945
# BsmtFinType2     38    2.602740
# BsmtExposure     38    2.602740
# BsmtQual         37    2.534247
# BsmtCond         37    2.534247
# BsmtFinType1     37    2.534247
# MasVnrArea        8    0.547945
# MasVnrType        8    0.547945
# Electrical        1    0.068493

# %%
# How many feature has missing value more than 1%?
print('There are ' + str(only_missing_data.shape[0]) + ' variables out of 81 that have missing values.')
# Out:
# There are 19 variables out of 81 that have missing values.

# %% [markdown]
# Let's find out the relationship between variables that has missing value with Sales Price

# %%
for feature in list(only_missing_data.index):
     # let's make a variable that indicates 1 if the observation was missing or zero otherwise
    df_train[feature] = np.where(df_train[feature].isnull(), 'missing', 'present')

    # let's calculate the mean SalePrice where the information is missing or present
    df_train.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Correlation analysis

# %%
# most correlated features
corr = df_train.corr()
top_corr_features = corr.index[abs(corr["SalePrice"])>0.6]
# top_corr_features = corr.index[abs(corr["SalePrice"])>0.4]
plt.figure(figsize=(6,4))
g = sns.heatmap(df_train[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
# Keep the most promising variables 
df4 = df_train[['SalePrice','OverallQual', 'TotalBsmtSF','GrLivArea', 'GarageCars']]

# %%
sns.distplot(df4['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
df4['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %%
df4.head(5)
# Out:
#    SalePrice  OverallQual  TotalBsmtSF  GrLivArea  GarageCars
# 0     208500            7          856       1710           2
# 1     181500            6         1262       1262           2
# 2     223500            7          920       1786           2
# 3     140000            7          756       1717           3
# 4     250000            8         1145       2198           3

# %% [markdown]
# ### Log Transform

# %%
import numpy as np
final_features=['SalePrice','OverallQual', 'TotalBsmtSF','GrLivArea', 'GarageCars']

for feature in final_features:
    df4[feature]=np.log(df4[feature])
# Out:
# C:\Users\ngloo\AppData\Local\Temp/ipykernel_476/2170218649.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4[feature]=np.log(df4[feature])

# %%
df4.head(5)
# Out:
#    SalePrice  OverallQual  TotalBsmtSF  GrLivArea  GarageCars
# 0  12.247694     1.945910     6.752270   7.444249    0.693147
# 1  12.109011     1.791759     7.140453   7.140453    0.693147
# 2  12.317167     1.945910     6.824374   7.487734    0.693147
# 3  11.849398     1.945910     6.628041   7.448334    1.098612
# 4  12.429216     2.079442     7.043160   7.695303    1.098612

# %%
sns.distplot(df4['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
df4['SalePrice'].skew()
# Out:
# 0.12133506220520406

# %% [markdown]
# 0.12  is way less than 1.8, this is good

# %% [markdown]
# Where are the Zeros??

# %%
X = df4[['OverallQual', 'TotalBsmtSF','GrLivArea', 'GarageCars']]
y = df4['SalePrice']

# %%
## Here we will check the percentage of nan values present in each feature
## 1 -step make the list of features which has missing values
features_with_na=[features for features in df4.columns if df[features].isnull().sum()>1]
## 2- step print the feature name and the percentage of missing values

for feature in features_with_na:
    print(feature, 100*np.round(df4[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# OverallQual 0.0  % missing values
# TotalBsmtSF 0.0  % missing values

# %%
print(df4.isnull().sum())
# Out:
# SalePrice      0
# OverallQual    0
# TotalBsmtSF    0
# GrLivArea      0
# GarageCars     0
# dtype: int64

# %%
for feature in final_features:
    count = (df4[feature] == 0).sum()
    print("Count of zeros in {} is {}".format(feature, count))
# Out:
# Count of zeros in SalePrice is 0
# Count of zeros in OverallQual is 2
# Count of zeros in TotalBsmtSF is 0
# Count of zeros in GrLivArea is 0
# Count of zeros in GarageCars is 369

# %%
sns.distplot(df4['GarageCars'])
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_476/2838482059.py in <module>
# ----> 1 sns.distplot(df4['GarageCars'])
#
# c:\users\ngloo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2672     if hist:
#    2673         if bins is None:
# -> 2674             bins = min(_freedman_diaconis_bins(a), 50)
#    2675         hist_kws.setdefault("alpha", 0.4)
#    2676         hist_kws.setdefault("density", norm_hist)
#
# c:\users\ngloo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#    2463         return int(np.sqrt(a.size))
#    2464     else:
# -> 2465         return int(np.ceil((a.max() - a.min()) / h))
#    2466
# ...

# %%
df4.to_csv('check.csv',index=False)

# %%
df4['GarageCars']=df4['GarageCars']+1
# Out:
# C:\Users\ngloo\AppData\Local\Temp/ipykernel_476/2855873880.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['GarageCars']=df4['GarageCars']+1

# %%
df4.to_csv('check.csv',index=False)
